# %% [markdown]
# # Credit Card Fraud Detection

# %%
import pandas as pd
import numpy as np

# %%
file_path = 'src/creditcard.csv'
data = pd.read_csv(file_path)
data.head().style.set_properties(cmap='coolwarm')
# Out:
# <style type="text/css">
# ...
